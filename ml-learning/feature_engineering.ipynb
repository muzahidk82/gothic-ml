# %%
print('Welcome to feature engineering')
# Out:
# Welcome to feature engineering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 20, 1)
y = 1 + x ** 2

# %%
X = x.reshape(-1, 1)

# %%
X.shape
# Out:
# (20, 1)

# %%
x.shape
# Out:
# (20,)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x, y, color="red")
plt.show()

# %%
from lab_utils_multi import zscore_normalize_features, run_gradient_descent_feng
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from lab_utils_multi import zscore_normalize_features, run_gradient_descent_feng
#
# ModuleNotFoundError: No module named 'lab_utils_multi'
